# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranitha3197/Statistical-Machine-learning/blob/main/sml_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/gym_members_exercise_tracking.csv')
df
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56    Male         88.3        1.71      180      157           60
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned  Unnamed: 9  Fat_Percentage  \
# ...

# %%
df['Gender']=df['Gender'].replace({'Male','Female'},{1,0})
df
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56       1         88.3        1.71      180      157           60
# 1     46       0         74.9        1.53      179      151           66
# 2     32       0         68.1        1.66      167      122           54
# 3     25       1         53.2        1.70      190      164           56
# 4     38       1         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24       1         87.1        1.74      187      158           67
# 969   25       1         66.6        1.61      184      166           56
# 970   59       0         60.4        1.76      194      120           53
# 971   32       1        126.4        1.83      198      146           62
# 972   46       1         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned  Unnamed: 9  Fat_Percentage  \
# ...

# %%
df.fillna(1, inplace=True)
df
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56       1         88.3        1.71      180      157           60
# 1     46       0         74.9        1.53      179      151           66
# 2     32       0         68.1        1.66      167      122           54
# 3     25       1         53.2        1.70      190      164           56
# 4     38       1         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24       1         87.1        1.74      187      158           67
# 969   25       1         66.6        1.61      184      166           56
# 970   59       0         60.4        1.76      194      120           53
# 971   32       1        126.4        1.83      198      146           62
# 972   46       1         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned  Unnamed: 9  Fat_Percentage  \
# ...

# %%
y=df['BMI']
y
# Out:
# 0      30.20
# 1      32.00
# 2      24.71
# 3      18.41
# 4      14.39
#        ...
# 968    28.77
# 969    25.69
# 970    19.50
# 971    37.74
# 972    33.38
# Name: BMI, Length: 973, dtype: float64

# %%
x=df.drop('BMI',axis=1)
x
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56       1         88.3        1.71      180      157           60
# 1     46       0         74.9        1.53      179      151           66
# 2     32       0         68.1        1.66      167      122           54
# 3     25       1         53.2        1.70      190      164           56
# 4     38       1         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24       1         87.1        1.74      187      158           67
# 969   25       1         66.6        1.61      184      166           56
# 970   59       0         60.4        1.76      194      120           53
# 971   32       1        126.4        1.83      198      146           62
# 972   46       1         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned  Unnamed: 9  Fat_Percentage  \
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
from sklearn.metrics import r2_score
y_pred=lr.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.9859022043816501

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_test,y_pred)
rmse=mse**0.5
rmse
# Out:
# 0.7975257712457563

# %%
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_test,y_pred)
mae
# Out:
# 0.5814240510494478

# %%
from sklearn.linear_model import Ridge
ridge = Ridge(alpha=1.0)
ridge.fit(x_train, y_train)
y_pred_ridge = ridge.predict(x_test)
r2_score(y_test,y_pred_ridge)
# Out:
# 0.9830479892176209

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_test,y_pred)
rmse=mse**0.5
rmse
# Out:
# 0.7975257712457563

# %%
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_test,y_pred)
mae
# Out:
# 0.5814240510494478

# %%
from sklearn.linear_model import Lasso
lasso = Lasso(alpha=1.0)
lasso.fit(x_train, y_train)
y_pred_lasso = lasso.predict(x_test)
r2_score(y_test,y_pred_lasso)
# Out:
# 0.7362917761455621

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_test,y_pred)
rmse=mse**0.5
rmse
# Out:
# 0.7975257712457563

# %%
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_test,y_pred)
mae
# Out:
# 0.5814240510494478

# %%
from sklearn.svm import SVR
svr = SVR(kernel='linear')
svr.fit(x_train, y_train)
y_pred_svr = svr.predict(x_test)
r2_score(y_test,y_pred_svr)
# Out:
# 0.9714898448106105

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_test,y_pred)
rmse=mse**0.5
rmse
# Out:
# 0.7975257712457563

# %%
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_test,y_pred)
mae
# Out:
# 0.5814240510494478
